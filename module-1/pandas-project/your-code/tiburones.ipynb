# %%
# Importo todas las herramientas que me van a hacer falta.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Hipótesis:
#
# #### Se producen más ataques en hombres que en mujeres, ya que los hombres asumen más actividades de riesgo que las mujeres.

# %%
# Abro el archivo y lo asigno a la variable df para poder trabajar con él.

df = pd.read_csv("attacks.csv", engine="python")


# Con df.head() veo las cinco primeras filas con todas sus columnas para hacerme una idea del fichero que tengo.

df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
# Veo la información básica de las columnas, el total de valores no-nulos y el tipo de sus variables.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
# Ver datos estadísticos básicos.

df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
# Veo el nombre de las columnas del archivo.

print(len(df.columns))

df.columns
# Out:
# 24
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Veo la cantidad de nulos de todas las columnas

df.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
# Reescribo la variable df con las columnas que me interesan. Paso de tener 24 columnas a tener 6.

df = df[['Year','Type', 'Country', 'Activity','Name', 'Sex ']]

df
# Out:
#          Year        Type    Country     Activity             Name Sex
# 0      2018.0     Boating        USA     Paddling      Julie Wolfe    F
# 1      2018.0  Unprovoked        USA     Standing  Adyson McNeely     F
# 2      2018.0     Invalid        USA      Surfing      John Denges    M
# 3      2018.0  Unprovoked  AUSTRALIA      Surfing             male    M
# 4      2018.0    Provoked     MEXICO  Free diving   Gustavo Ramos     M
# ...       ...         ...        ...          ...              ...  ...
# 25718     NaN         NaN        NaN          NaN              NaN  NaN
# 25719     NaN         NaN        NaN          NaN              NaN  NaN
# 25720     NaN         NaN        NaN          NaN              NaN  NaN
# 25721     NaN         NaN        NaN          NaN              NaN  NaN
# 25722     NaN         NaN        NaN          NaN              NaN  NaN
#
# [25723 rows x 6 columns]

# %%
# Obtengo información de la columna ['Sex ']

df['Sex '].describe
# Out:
# <bound method NDFrame.describe of 0          F
# 1          F
# 2          M
# 3          M
# 4          M
#         ...
# 25718    NaN
# 25719    NaN
# 25720    NaN
# 25721    NaN
# 25722    NaN
# Name: Sex , Length: 25723, dtype: object>

# %%
# Veo el total de duplicados en la columna ['Sex ']

df['Sex '].duplicated().sum()
# Out:
# 25716

# %%
# Veo cuantos duplicados en forma booleana hay en la columna ['Sex '] 

df['Sex '].duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 25718     True
# 25719     True
# 25720     True
# 25721     True
# 25722     True
# Name: Sex , Length: 25723, dtype: bool

# %%
# Veo los registros nulos de todas las columnas

df.isnull().sum()
# Out:
# Year        19423
# Type        19425
# Country     19471
# Activity    19965
# Name        19631
# Sex         19986
# dtype: int64

# %%
# Elimino los registros duplicados

df = df.drop_duplicates()
df
# Out:
#         Year        Type             Country      Activity  \
# 0     2018.0     Boating                 USA      Paddling
# 1     2018.0  Unprovoked                 USA      Standing
# 2     2018.0     Invalid                 USA       Surfing
# 3     2018.0  Unprovoked           AUSTRALIA       Surfing
# 4     2018.0    Provoked              MEXICO   Free diving
# ...      ...         ...                 ...           ...
# 6298     0.0  Unprovoked           AUSTRALIA  Pearl diving
# 6299     0.0  Unprovoked                 USA      Swimming
# 6300     0.0  Unprovoked              PANAMA           NaN
# 6301     0.0  Unprovoked  CEYLON (SRI LANKA)      Swimming
# 6302     NaN         NaN                 NaN           NaN
#
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6298                  Ahmun    M
# 6299  Coast Guard personnel    M
# 6300        Jules Patterson    M
# 6301                   male    M
# 6302                    NaN  NaN
#
# [6227 rows x 6 columns]

# %%
# Veo el tipo de datos de todas las columnas

df.dtypes
# Out:
# Year        float64
# Type         object
# Country      object
# Activity     object
# Name         object
# Sex          object
# dtype: object

# %%
# Como los datos de ['Year'] son flotantes los tengo que convertir a int. 
# Pero tengo que convertir los NaN primero a valores int (en este caso 0)

df['Year'] = df['Year'].fillna(0).astype(np.int64)

df['Year']
# Out:
# <ipython-input-184-7d84121a1124>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].fillna(0).astype(np.int64)
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
#         ...
# 6298       0
# 6299       0
# 6300       0
# 6301       0
# 6302       0
# Name: Year, Length: 6227, dtype: int64

# %%
# Compruebo que ha cambiado el tipo

df.dtypes
# Out:
# Year         int64
# Type        object
# Country     object
# Activity    object
# Name        object
# Sex         object
# dtype: object

# %%
df
# Out:
#       Year        Type             Country      Activity  \
# 0     2018     Boating                 USA      Paddling
# 1     2018  Unprovoked                 USA      Standing
# 2     2018     Invalid                 USA       Surfing
# 3     2018  Unprovoked           AUSTRALIA       Surfing
# 4     2018    Provoked              MEXICO   Free diving
# ...    ...         ...                 ...           ...
# 6298     0  Unprovoked           AUSTRALIA  Pearl diving
# 6299     0  Unprovoked                 USA      Swimming
# 6300     0  Unprovoked              PANAMA           NaN
# 6301     0  Unprovoked  CEYLON (SRI LANKA)      Swimming
# 6302     0         NaN                 NaN           NaN
#
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6298                  Ahmun    M
# 6299  Coast Guard personnel    M
# 6300        Jules Patterson    M
# 6301                   male    M
# 6302                    NaN  NaN
#
# [6227 rows x 6 columns]

# %%
# Quito los NaN

df.dropna(inplace=True)

df
# Out:
# <ipython-input-187-9d0fda8b45b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#       Year        Type             Country      Activity  \
# 0     2018     Boating                 USA      Paddling
# 1     2018  Unprovoked                 USA      Standing
# 2     2018     Invalid                 USA       Surfing
# 3     2018  Unprovoked           AUSTRALIA       Surfing
# 4     2018    Provoked              MEXICO   Free diving
# ...    ...         ...                 ...           ...
# 6296     0  Unprovoked           AUSTRALIA      Swimming
# 6297     0  Unprovoked           AUSTRALIA        Diving
# 6298     0  Unprovoked           AUSTRALIA  Pearl diving
# 6299     0  Unprovoked                 USA      Swimming
# 6301     0  Unprovoked  CEYLON (SRI LANKA)      Swimming
#
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6296               Arab boy    M
# 6297                   male    M
# 6298                  Ahmun    M
# 6299  Coast Guard personnel    M
# 6301                   male    M
#
# [5194 rows x 6 columns]

# %%
# Veo que tipos de valores hay dentro de ['Sex ']

df['Sex '].value_counts()
# Out:
# M      4617
# F       573
# M         2
# N         1
# lli       1
# Name: Sex , dtype: int64

# %%
df = df.drop(df[df['Sex ']== N].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-4825c404a014> in <module>
# ----> 1 df = df.drop(df[df['Sex ']== N].index)
#
# NameError: name 'N' is not defined

# %%
# Elimino los valores < 1969 (año)

df = df.drop(df[df['Year']<1969].index)

df
# Out:
#       Year        Type    Country  \
# 0     2018     Boating        USA
# 1     2018  Unprovoked        USA
# 2     2018     Invalid        USA
# 3     2018  Unprovoked  AUSTRALIA
# 4     2018    Provoked     MEXICO
# ...    ...         ...        ...
# 3412  1970  Unprovoked       IRAQ
# 3413  1970  Unprovoked       IRAQ
# 3414  1970  Unprovoked       IRAQ
# 3415  1970  Unprovoked       IRAQ
# 3888  1971  Unprovoked     TURKEY
#
#                                                Activity             Name Sex
# 0                                              Paddling      Julie Wolfe    F
# 1                                              Standing  Adyson McNeely     F
# 2                                               Surfing      John Denges    M
# 3                                               Surfing             male    M
# 4                                           Free diving   Gustavo Ramos     M
# ...                                                 ...              ...  ...
# 3412                               Washing cooking pans           female    F
# 3413                          Washing clothes on stairs           female    F
# 3414                                           Swimming             male    M
# 3415  Fishing, trying to catch the end of his fishin...             male    M
# 3888                                           Swimming  ?brahim Karagöz    M
#
# [2963 rows x 6 columns]

# %%
df['Year'].value_counts()
# Out:
# 2015    134
# 2017    119
# 2011    117
# 2013    112
# 2014    110
# 2016    109
# 2009    109
# 2008    105
# 2007    104
# 2012     98
# 2010     97
# 2006     91
# 2005     90
# 2000     83
# 2003     82
# 2004     82
# 2002     80
# 2001     75
# 1995     63
# 1999     59
# 1998     59
# 2018     51
# 1997     50
# 1996     49
# 1989     49
# 1992     49
# 1988     48
# 1994     47
# 1981     43
# 1983     43
# 1993     43
# 1975     37
# 1984     36
# 1990     35
# 1991     35
# 1982     34
# 1970     34
# 1980     33
# 1974     32
# 1985     30
# 1986     29
# 1987     27
# 1972     26
# 1976     24
# 1977     21
# 1973     21
# 1979     20
# 1978     20
# 1971     19
# Name: Year, dtype: int64

# %%
# Veo que tipos de valores hay dentro de ['Sex ']

df['Sex '].value_counts()
# Out:
# M      2515
# F       445
# M         2
# lli       1
# Name: Sex , dtype: int64

# %%
df
# Out:
#       Year        Type    Country  \
# 0     2018     Boating        USA
# 1     2018  Unprovoked        USA
# 2     2018     Invalid        USA
# 3     2018  Unprovoked  AUSTRALIA
# 4     2018    Provoked     MEXICO
# ...    ...         ...        ...
# 3412  1970  Unprovoked       IRAQ
# 3413  1970  Unprovoked       IRAQ
# 3414  1970  Unprovoked       IRAQ
# 3415  1970  Unprovoked       IRAQ
# 3888  1971  Unprovoked     TURKEY
#
#                                                Activity             Name Sex
# 0                                              Paddling      Julie Wolfe    F
# 1                                              Standing  Adyson McNeely     F
# 2                                               Surfing      John Denges    M
# 3                                               Surfing             male    M
# 4                                           Free diving   Gustavo Ramos     M
# ...                                                 ...              ...  ...
# 3412                               Washing cooking pans           female    F
# 3413                          Washing clothes on stairs           female    F
# 3414                                           Swimming             male    M
# 3415  Fishing, trying to catch the end of his fishin...             male    M
# 3888                                           Swimming  ?brahim Karagöz    M
#
# [2963 rows x 6 columns]

# %%
df = df.drop(df['Sex '] != "M").index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-199-9c972b5e8cf3> in <module>
# ----> 1 df = df.drop(df['Sex '] != "M").index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: '[ True  True False ... False False False] not found in axis'

# %%
# Hacer los bins

## Creating bins
# bins to cut
bins = list(range(1980,2021,10))
# Name for each bin
labels = [f"{str(year)[-2:]}'s" for year in range(1980,2020,10)]
df_clean["decade"]=pd.cut(
    df_clean["year"],
    bins=bins,
    labels=labels
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-200-db16ad0162de> in <module>
#       7 labels = [f"{str(year)[-2:]}'s" for year in range(1980,2020,10)]
#       8 df_clean["decade"]=pd.cut(
# ----> 9     df_clean["year"],
#      10     bins=bins,
#      11     labels=labels
#
# NameError: name 'df_clean' is not defined

# %%
df1 = df[(df['Sex '] == 'F')]

df
# Out:
#       Year        Type             Country      Activity  \
# 0     2018     Boating                 USA      Paddling
# 1     2018  Unprovoked                 USA      Standing
# 2     2018     Invalid                 USA       Surfing
# 3     2018  Unprovoked           AUSTRALIA       Surfing
# 4     2018    Provoked              MEXICO   Free diving
# ...    ...         ...                 ...           ...
# 6298     0  Unprovoked           AUSTRALIA  Pearl diving
# 6299     0  Unprovoked                 USA      Swimming
# 6300     0  Unprovoked              PANAMA           NaN
# 6301     0  Unprovoked  CEYLON (SRI LANKA)      Swimming
# 6302     0         NaN                 NaN           NaN
#
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6298                  Ahmun    M
# 6299  Coast Guard personnel    M
# 6300        Jules Patterson    M
# 6301                   male    M
# 6302                    NaN  NaN
#
# [6227 rows x 6 columns]

# %%
df2 = df[(df['Sex '] == 'M')]

df
# Out:
#       Year        Type             Country      Activity  \
# 0     2018     Boating                 USA      Paddling
# 1     2018  Unprovoked                 USA      Standing
# 2     2018     Invalid                 USA       Surfing
# 3     2018  Unprovoked           AUSTRALIA       Surfing
# 4     2018    Provoked              MEXICO   Free diving
# ...    ...         ...                 ...           ...
# 6298     0  Unprovoked           AUSTRALIA  Pearl diving
# 6299     0  Unprovoked                 USA      Swimming
# 6300     0  Unprovoked              PANAMA           NaN
# 6301     0  Unprovoked  CEYLON (SRI LANKA)      Swimming
# 6302     0         NaN                 NaN           NaN
#
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6298                  Ahmun    M
# 6299  Coast Guard personnel    M
# 6300        Jules Patterson    M
# 6301                   male    M
# 6302                    NaN  NaN
#
# [6227 rows x 6 columns]

# %%
df['Sex '] = df['Sex '].fillna(0).astype(np.object)


df
# Out:
# <ipython-input-66-b16633f00f6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex '] = df['Sex '].fillna(0).astype(np.object)
#       Year        Type             Country      Activity  \
# 0     2018     Boating                 USA      Paddling
# 1     2018  Unprovoked                 USA      Standing
# 2     2018     Invalid                 USA       Surfing
# 3     2018  Unprovoked           AUSTRALIA       Surfing
# 4     2018    Provoked              MEXICO   Free diving
# ...    ...         ...                 ...           ...
# 6298     0  Unprovoked           AUSTRALIA  Pearl diving
# 6299     0  Unprovoked                 USA      Swimming
# 6300     0  Unprovoked              PANAMA           NaN
# 6301     0  Unprovoked  CEYLON (SRI LANKA)      Swimming
# 6302     0         NaN                 NaN           NaN
#
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6298                  Ahmun    M
# 6299  Coast Guard personnel    M
# 6300        Jules Patterson    M
# 6301                   male    M
# 6302                    NaN    0
#
# [6227 rows x 6 columns]

# %%
df.groupby(['Sex ', 'Year']).count()
# Out:
#            Type  Country  Activity  Name
# Sex  Year
# 0    0        8        7         8     4
#      1617     1        1         0     1
#      1637     1        1         1     1
#      1733     1        1         0     0
#      1776     1        1         0     1
# ...         ...      ...       ...   ...
# M    2005     1        1         1     1
#      2014     1        1         1     1
# N    1801     1        0         1     1
#      1934     1        1         1     1
# lli  2004     1        1         1     1
#
# [498 rows x 4 columns]

# %%
df['Sex '].value_counts()
# Out:
# M      5031
# F       632
# M         2
# N         2
# lli       1
# .         1
# Name: Sex , dtype: int64

# %%
df.isnull().sum()
# Out:
# Year          0
# Type          5
# Country      51
# Activity    531
# Name        206
# Sex         558
# dtype: int64

# %%
df.dropna(subset=['bin'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-48a995ea420c> in <module>
# ----> 1 df.dropna(subset=['bin'],inplace=True)
#       2
#       3 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4746             check = indices == -1
#    4747             if check.any():
# -> 4748                 raise KeyError(list(np.compress(check, subset)))
#    4749             agg_obj = self.take(indices, axis=agg_axis)
#    4750
#
# KeyError: ['bin']

# %%
 = (df['issue_date'] > '2018-12-31') & (df['issue_date'] <= '2019-12-31')

# %%
# Compruebo que se han eliminado todos los duplicados

df.duplicated().sum()

# %%
# Veo las subsecciones que hay y cuántos valores poseen

df['Sex '].value_counts()

# %%
# Veo los subregistros de la columna ['Sex ']

df['Sex '].value_counts()

# %%
df[(df['Activity'].isnull())]['Injury'].value_counts()

# %%
df.groupby(['Sex '])

# %%
# Muestra solo columnas donde el número de valores nulos fue mayor que cero.

null_cols = df.isnull().sum()
print(null_cols[null_cols > 0])

# %%
# Elimino las columnas que tienen más de 20.000 nulos

drop_cols = list(null_cols[null_cols > 20000].index) 
data = df.drop(drop_cols, axis=1)
data

# %%
# Veo como va de momento la limpieza (quedan 19 columnas)

data.info()

# %%
# Elimino las columnas que no tienen mucho sentido

columnas = df.drop(columns=['Date','pdf','href formula','href', 'Case Number.1', 'Case Number.2', 'Unnamed: 22', 'Unnamed: 23', 'Name'])

columnas

# %%
# Pongo las columnas que son floats a integers

# Primero - Paso todos los números a floats, porque los NaN son floats

columnas2[['Year', 'original order']].astype(float)

# Segundo - Sustituyo los NaN por 0

columnas2.fillna(0)

# Tercero - Cambio las dos columnas a tipo int

columnas2[['Year', 'original order']].astype(int)

columnas2

# %%
for columna in columnas:
    columna = columna.astype(float)
    print (columna)

# %%
columnas.describe()
