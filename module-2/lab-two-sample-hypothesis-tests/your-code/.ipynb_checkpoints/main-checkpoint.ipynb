# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Independent Sample T-tests
#
# In this challenge, we will be using the Pokemon dataset. Before applying statistical methods to this data, let's first examine the data.
#
# To load the data, run the code below.

# %%
# Run this code:
pokemon = pd.read_csv('../pokemon.csv')

# %% [markdown]
# Let's start off by looking at the `head` function in the cell below.

# %%
# Your code here:
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# The first thing we would like to do is compare the legendary Pokemon to the regular Pokemon. To do this, we should examine the data further. What is the count of legendary vs. non legendary Pokemons?

# %%
# Your code here:
#pokemon.Legendary.value_counts()
print(f"{pokemon.Legendary.value_counts()[0]} regular pokemon VS {pokemon.Legendary.value_counts()[1]} legendary pokemon.")
# Out:
# 735 regular pokemon VS 65 legendary pokemon.

# %% [markdown]
# Compute the mean and standard deviation of the total points for both legendary and non-legendary Pokemon.

# %%
legendary = pokemon[pokemon["Legendary"] == True]
regular = pokemon[pokemon["Legendary"] == False]
print(f" Lengendary:\n Mean = {legendary.Total.mean()}\n Std = {legendary.Total.std()}\n\n")
print(f" Regular:\n Mean = {regular.Total.mean()}\n Std = {regular.Total.std()}")
# Out:
#  Lengendary:
#  Mean = 637.3846153846154
#  Std = 60.93738905315344
#
#
#  Regular:
#  Mean = 417.21360544217686
#  Std = 106.76041745713005

# %% [markdown]
# The computation of the mean might give us a clue regarding how the statistical test may turn out; However, it certainly does not prove whether there is a significant difference between the two groups.
#
# In the cell below, use the `ttest_ind` function in `scipy.stats` to compare the the total points for legendary and non-legendary Pokemon. Since we do not have any information about the population, assume the variances are not equal.

# %%
from scipy.stats import ttest_ind

# %%
Ho = "Legendary vs Regular points are significally similar"
H = "Legendary vs Regular points are significally different"

pvalue = ttest_ind(regular.Total,legendary.Total,equal_var = False).pvalue
alpha = 0.0000000000000000000000000000000000000000000001

print(pvalue)
if pvalue < alpha: # Acepto H
    print(f"Ho may be rejected! -----> {H} with a CI of almost {(1-alpha)*100}%")
else: # Acepto Ho
    print(f"Ho may not be rejected! -----> {Ho} with a CI of almost {(1-alpha)*100}%")
# Out:
# 9.357954335957444e-47
# Ho may be rejected! -----> Legendary vs Regular points are significally different with a CI of almost 100.0%

# %% [markdown]
# What do you conclude from this test? Write your conclusions below.

# %%
# Your conclusions here:
#Legendary vs Regular points are significally different

# %% [markdown]
# How about we try to compare the different types of pokemon? In the cell below, list the types of Pokemon from column `Type 1` and the count of each type.

# %%
# Your code here:
pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# Since water is the largest group of Pokemon, compare the mean and standard deviation of water Pokemon to all other Pokemon.

# %%
# Your code here:
water = pokemon[pokemon["Type 1"] == 'Water'].Total
other = pokemon[pokemon["Type 1"] != 'Water'].Total

print(f" WATER:\n Mean = {water.mean()}\n Std = {water.std()}\n\n")
print(f" OTHER:\n Mean = {other.mean()}\n Std = {other.std()}")
# Out:
#  WATER:
#  Mean = 430.45535714285717
#  Std = 113.1882660643146
#
#
#  OTHER:
#  Mean = 435.85901162790697
#  Std = 121.0916823020807

# %% [markdown]
# Perform a hypothesis test comparing the mean of total points for water Pokemon to all non-water Pokemon. Assume the variances are equal.

# %%
# Your code here:
Ho = "Water pokemon points are similar to the other pokemon"
H = "Water pokemon points are significally different from the other"

pvalue = ttest_ind(water,other,equal_var = True).pvalue
alpha = 0.05

print(f"Pvalue = {pvalue}\n")
if pvalue < alpha: # Acepto H
    print(f"Ho may be rejected.\n\nCONCLUSION:   {H} with a CI of almost {(1-alpha)*100}%")
else: # Acepto Ho
    print(f"Ho may not be rejected.\n\nCONCLUSION:   {Ho} with a CI of almost {(1-alpha)*100}%")
# Out:
# Pvalue = 0.6587140317488793
#
# Ho may not be rejected.
#
# CONCLUSION:   Water pokemon points are similar to the other pokemon with a CI of almost 95.0%

# %% [markdown]
# Write your conclusion below.

# %%
# Your conclusions here:
#Water pokemon points are similar to the other pokemon with a CI of almost 95.0%

# %% [markdown]
# # Challenge 2 - Matched Pairs Test
#
# In this challenge we will compare dependent samples of data describing our Pokemon. Our goal is to see whether there is a significant difference between each Pokemon's defense and attack scores. Our hypothesis is that the defense and attack scores are equal. In the cell below, import the `ttest_rel` function from `scipy.stats` and compare the two columns to see if there is a statistically significant difference between them.

# %%
from scipy.stats import ttest_rel

# %%
# Your code here:
Ho = "Defense and attack scores are equal"
H = "There is a significant difference between each Pokemon's defense and attack scores"

pvalue = ttest_rel(pokemon.Attack,pokemon.Defense).pvalue
alpha = 0.05

print(f"Pvalue = {pvalue}\n")
if pvalue < alpha: # Acepto H
    print(f"Ho may be rejected.\n\nCONCLUSION:   {H}, with a CI of {(1-alpha)*100}%")
else: # Acepto Ho
    print(f"Ho may not be rejected.\n\nCONCLUSION:   {Ho}, with a CI of {(1-alpha)*100}%")
# Out:
# Pvalue = 1.7140303479358558e-05
#
# Ho may be rejected.
#
# CONCLUSION:   There is a significant difference between each Pokemon's defense and attack scores, with a CI of 95.0%

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:
# There is a significant difference between each Pokemon's defense and attack scores, with a CI of 95.0%

# %% [markdown]
# We are also curious about whether therer is a significant difference between the mean of special defense and the mean of special attack. Perform the hypothesis test in the cell below.

# %%
# Your code here:
Ho = "There is not a significant difference between special defense mean andspecial attack mean"
H = "There is a significant difference between special defense mean andspecial attack mean"

pvalue = ttest_rel(pokemon['Sp. Def'],pokemon['Sp. Atk']).pvalue
alpha = 0.05

print(f"Pvalue = {pvalue}\n")
if pvalue < alpha: # Acepto H
    print(f"Ho may be rejected.\n\nCONCLUSION:   {H}, with a CI of {(1-alpha)*100}%")
else: # Acepto Ho
    print(f"Ho may not be rejected.\n\nCONCLUSION:   {Ho}, with a CI of {(1-alpha)*100}%")
# Out:
# Pvalue = 0.3933685997548122
#
# Ho may not be rejected.
#
# CONCLUSION:   There is not a significant difference between special defense mean andspecial attack mean, with a CI of 95.0%

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:
# There is not a significant difference between special defense mean andspecial attack mean, with a CI of 95.0%

# %% [markdown]
# As you may recall, a two sample matched pairs test can also be expressed as a one sample test of the difference between the two dependent columns.
#
# Import the `ttest_1samp` function and perform a one sample t-test of the difference between defense and attack. Test the hypothesis that the difference between the means is zero. Confirm that the results of the test are the same.

# %%
from scipy.stats import ttest_1samp

# %%
# Your code here:
Ho = "The difference between the means is not zero"
H = "The difference between the means is zero"

pvalue = ttest_1samp(pokemon.Defense - pokemon.Attack,0).pvalue


print(f"Pvalue = {pvalue}\n")
if pvalue < alpha: # Acepto H
    print(f"Ho may be rejected.\n\nCONCLUSION:   {H}, with a CI of {(1-alpha)*100}%")
else: # Acepto Ho
    print(f"Ho may not be rejected.\n\nCONCLUSION:   {Ho}, with a CI of {(1-alpha)*100}%")
# Out:
# Pvalue = 1.7140303479358558e-05
#
# Ho may be rejected.
#
# CONCLUSION:   The difference between the means is zero, with a CI of 95.0%

# %% [markdown]
# # Bonus Challenge - The Chi-Square Test
#
# The Chi-Square test is used to determine whether there is a statistically significant difference in frequencies. In other words, we are testing whether there is a relationship between categorical variables or rather when the variables are independent. This test is an alternative to Fisher's exact test and is used in scenarios where sample sizes are larger. However, with a large enough sample size, both tests produce similar results. Read more about the Chi Squared test [here](https://en.wikipedia.org/wiki/Chi-squared_test).
#
# In the cell below, create a contingency table using `pd.crosstab` comparing whether a Pokemon is legenadary or not and whether the Type 1 of a Pokemon is water or not.

# %%
# Your code here:
df = pd.crosstab(index = pokemon['Legendary'], columns = pokemon['Type 1'] == 'Water')
df
# Out:
# Type 1     False  True
# Legendary
# False        627    108
# True          61      4

# %% [markdown]
# Perform a chi-squared test using the `chi2_contingency` function in `scipy.stats`. You can read the documentation of the function [here](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.chi2_contingency.html).

# %%
from scipy.stats import chi2_contingency

# %%
# Your code here:
pvalue = chi2_contingency(df)[1]
print(pvalue)
# Out:
# 0.08625467249550949

# %% [markdown]
# Based on a 95% confidence, should we reject the null hypothesis?

# %%
# Your answer here:
Ho = "There are not significantly more legendary water pokemon"
H = "There are significantly more legendary water pokemon"

pvalue = chi2_contingency(df)[1]
alpha = 0.05

print(f"Pvalue = {pvalue}\n")
if pvalue < alpha: # Acepto H
    print(f"Ho may be rejected.\n\nCONCLUSION:   {H}, with a CI of {(1-alpha)*100}%")
else: # Acepto Ho
    print(f"Ho may not be rejected.\n\nCONCLUSION:   {Ho}, with a CI of {(1-alpha)*100}%")
# Out:
# Pvalue = 0.08625467249550949
#
# Ho may not be rejected.
#
# CONCLUSION:   There are not significantly more legendary water pokemon, with a CI of 95.0%
