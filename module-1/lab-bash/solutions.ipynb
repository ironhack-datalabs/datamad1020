# %% [markdown]
# #### Imprime en consola Hello World.

# %% [markdown]
# Your solution here:

# %% [markdown]
# #### Crea un directorio nuevo llamado new_dir.

# %% [markdown]
# Your solution here:

# %% [markdown]
# #### Elimina ese directorio.

# %% [markdown]
# Your solution here:
