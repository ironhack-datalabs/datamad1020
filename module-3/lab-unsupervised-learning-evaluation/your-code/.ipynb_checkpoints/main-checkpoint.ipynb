# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
km = KMeans()
km.fit(X)
label = km.predict(X)
silhouette_score(X,label)
# Out:
# 0.5369913269089153

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
km = KMeans(n_clusters=5)
km.fit(X)
label = km.predict(X)
silhouette_score(X,label)
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
km = KMeans(n_clusters =3)
km.fit(X)
label = km.predict(X)
silhouette_score(X,label)
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %% [markdown]
# **distorsion**

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.datasets import make_blobs

model = KMeans()
visualizer = KElbowVisualizer(model, k=(4,15))
visualizer.fit(X)        #distortion, nos dice que con 3, veamos si es cierto.
visualizer.show();

# %%
km = KMeans(n_clusters =7)
km.fit(X)
label = km.predict(X)
silhouette_score(X,label)
# Out:
# 0.5621677013863717

# %% [markdown]
# **calinski_harabasz**

# %%
modelo2 = KMeans()
visualizer1 = KElbowVisualizer(
    modelo2, k=(4,12), metric='calinski_harabasz')
visualizer1.fit(X)        #distortion, nos dice que con 3, veamos si es cierto.
visualizer1.show();
# Out:
# C:\Users\Adrian\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\Adrian\anaconda3\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
km = KMeans(n_clusters=6) #nos indico en el 6, pero empeoró en relacion al k=3
km.fit(X)
label = km.predict(X)
silhouette_score(X,label)
# Out:
# 0.5656413100386389

# %%
modelo2 = KMeans()
visualizer1 = KElbowVisualizer(
    modelo2, k=(2,15), metric='silhouette')
visualizer1.fit(X)        #silhoute, nos dice que con 6, igual que antes
visualizer1.show();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %% [markdown]
# **distorsion**

# %%
from sklearn.cluster import AgglomerativeClustering
agg = AgglomerativeClustering()
vis = KElbowVisualizer(
    agg, k=(4,12))
vis.fit(X)        #distortion, nos dice que con 7.
vis.show();

# %%
 #nos indico en el 7
clustering = AgglomerativeClustering(7).fit(X)
pred = clustering.fit_predict(X)
silhouette_score(X,pred)
# Out:
# 0.5369215536550145

# %% [markdown]
# **silhouette**

# %%
agg1 = AgglomerativeClustering()
vis1 = KElbowVisualizer(
    agg1, k=(2,15),metric = "silhouette")
vis1.fit(X)        #distortion, nos dice que con 6, y que tenemos un 0.52
vis1.show();

# %%
clustering1 = AgglomerativeClustering(6).fit(X)
pred1 = clustering1.fit_predict(X)
silhouette_score(X,pred1)
# Out:
# 0.5270523448339738

# %% [markdown]
# **calinski_harabasz**

# %%
agg2 = AgglomerativeClustering()
vis2 = KElbowVisualizer(
    agg2, k=(2,15),metric = "calinski_harabasz")
vis2.fit(X)         #nos dice que con 4
vis2.show();

# %%
clustering2 = AgglomerativeClustering(4).fit(X)
pred2 = clustering2.fit_predict(X)
silhouette_score(X,pred2)
# Out:
# 0.560672694839427

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
km = KMeans(n_clusters =3)
km.fit(X)
label = km.predict(X)


X['cluster'] = label
plt.scatter(X.values[:, 1], X.values[:, 2], c=label); #unicamente cambiamos el número de las columnas para agrupar las que 
#queramos.

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
tp = pca.fit_transform(X)
sns.scatterplot(tp[:,0],tp[:,1], hue=y_pred);

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.
