# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans

# Se trata de la distancia entre una muestra y el conglomerado más cercano del que la muestra no forma parte.

km = KMeans(n_clusters=8)

km.fit(X)
# Out:
# KMeans()

# %%
models = [KMeans(i) for i in range(1,9)]
scores = [m.fit(X).score(X) for m in models]

scores
# Out:
# [-17592296.383508474,
#  -4543749.614531862,
#  -2370689.6867829696,
#  -1333139.2086165312,
#  -935752.2742960755,
#  -648422.2834974247,
#  -412137.5091004584,
#  -323211.55263465445]

# %%
plt.plot(range(1,9),scores);

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
km1 = KMeans(n_clusters=5)

km1.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
models1 = [KMeans(i) for i in range(1,6)]
scores1 = [m.fit(X).score(X) for m in models1]

scores
# Out:
# [-17592296.383508474,
#  -4543749.614531862,
#  -2370689.6867829696,
#  -1333139.2086165312,
#  -935752.2742960755,
#  -648422.2834974247,
#  -412137.5091004584,
#  -323211.55263465445]

# %%
plt.plot(range(1,6),scores1);

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
km2 = KMeans(n_clusters=3)

km2.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
models2 = [KMeans(i) for i in range(1,4)]
scores2 = [m.fit(X).score(X) for m in models2]

scores
# Out:
# [-17592296.383508474,
#  -4543749.614531862,
#  -2370689.6867829696,
#  -1333139.2086165312,
#  -935752.2742960755,
#  -648422.2834974247,
#  -412137.5091004584,
#  -323211.55263465445]

# %%
plt.plot(range(1,4),scores2);

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer

# Distorsion

# Por defecto viene la métrica de distorsion

model = KMeans(X)
visualizer = KElbowVisualizer(model, timings=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();       # Finalize and render the figure

# %%
# Silhouette

model = KMeans()
visualizer = KElbowVisualizer(model, metric='silhouette', timings=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();       # Finalize and render the figure
# Out:
# C:\Users\arroy\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\arroy\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\arroy\anaconda3\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
# Calinski_Harabaz

model = KMeans()
visualizer = KElbowVisualizer(model, metric='calinski_harabasz', timings=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();       # Finalize and render the figure

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering

# Distorsion

model = AgglomerativeClustering().fit(X)
visualizer = KElbowVisualizer(model, timings=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();       # Finalize and render the figure

# %%
# Silhouette

model = AgglomerativeClustering().fit(X)
visualizer = KElbowVisualizer(model, metric='silhouette', timings=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();       # Finalize and render the figure

# %%
# Calinski_Harabaz

model = AgglomerativeClustering().fit(X)
visualizer = KElbowVisualizer(model, metric='calinski_harabasz', timings=False)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();       # Finalize and render the figure

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

pca
# Out:
# PCA(n_components=2)

# %%
pca_fit = pca.fit(X)

pca_fit
# Out:
# PCA(n_components=2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.99809123, 0.00173592])

# %%
pca.transform(X)
# Out:
# array([[ 3.18562979e+02,  2.14921307e+01],
#        [ 3.03097420e+02, -5.36471768e+00],
#        [ 4.38061133e+02, -6.53730945e+00],
#        [ 7.33240139e+02,  1.92729032e-01],
#        [-1.15714285e+01,  1.84899946e+01],
#        [ 7.03231192e+02, -3.32158674e-01],
#        [ 5.42971581e+02, -1.35189666e+01],
#        [ 5.48401860e+02,  1.14494324e+01],
#        [ 2.98036863e+02, -8.18015784e+00],
#        [ 2.98049553e+02, -7.10154294e+00],
#        [ 7.63079712e+02, -8.33431723e+00],
#        [ 5.32943228e+02, -1.42876338e+01],
#        [ 5.72834410e+02, -2.10050143e+01],
#        [ 4.02925358e+02, -1.61026352e+01],
#        [ 8.00053394e+02, -1.21184472e+01],
#        [ 5.63245578e+02,  2.21482866e+00],
#        [ 5.33379651e+02,  1.08048022e+01],
#        [ 3.83317591e+02,  8.47741982e+00],
#        [ 9.33118387e+02, -8.35447844e+00],
#        [ 9.84031775e+01,  1.43926594e+01],
#        [ 3.35935940e+01,  2.55679565e+01],
#        [ 2.31464375e+01,  1.81747309e+00],
# ...

# %%
plt.scatter(pca.transform(X),y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-c193945a991c> in <module>
# ----> 1 plt.scatter(pca.transform(X),y)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

sne = TSNE(n_components=2, perplexity=30, n_iter=1000, learning_rate=200)

sne
# Out:
# TSNE(learning_rate=200, perplexity=30)

# %%
data_t = TSNE.fit_transform

data_t
# Out:
# <function sklearn.manifold._t_sne.TSNE.fit_transform(self, X, y=None)>
